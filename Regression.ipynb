# %% [markdown]
# <h1>Linear Regression Models using Housing Dataset</h1>

# %%
#Importing Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.linear_model import ElasticNet
from sklearn.svm import SVR
from sklearn import metrics
import seaborn as sns

# %%
#Reading data
Housing_data = pd.read_csv(r'C:\Users\palak\Desktop\Housing.csv')

# %%
Housing_data
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
#I'm using heatmap for the columns to check the correlation.
fig_plt = plt.gcf() 
fig_size = fig_plt.get_size_inches()
fig_plt.set_size_inches(fig_size * 2.5)
sns.heatmap(Housing_data.corr(),annot=True)
plt.show()

# %%
#From the heatmap we can say that TAx is highly correlated with the RAD,NOX and INDUS and therefore we would be using them as features and target variable. 
X=Housing_data[['RAD','NOX','INDUS']]
y=Housing_data['TAX']

# %%
#Splitting the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42)

# %%
#Using Linear Regression
linear=LinearRegression()
linear.fit(X_train,y_train)
predicted_linear = linear.predict(X_test) 
print("Accuracy:",linear.score(X_test, y_test))
#Plotting the prediction
figure, ax = plt.subplots()
ax.scatter(y_test, predicted_linear)
ax.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red')
ax.set_xlabel('Actual')
ax.set_ylabel('Predicted')
ax.set_title("Actual Truth vs Predicted")
plt.show()
# Out:
# Accuracy: 0.8868889853636649

# %%
#Using Elastic Net
en=ElasticNet()
en.fit(X_train,y_train)
predicted_en = en.predict(X_test)
print("Accuracy:",en.score(X_test, y_test))
#Plotting the prediction
figure, ax = plt.subplots()
ax.scatter(y_test, predicted_en)
ax.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red')
ax.set_xlabel('Actual')
ax.set_ylabel('Predicted')
ax.set_title("Actual Truth vs Predicted")
plt.show()
# Out:
# Accuracy: 0.8875968112468247

# %%
#Using Ridge Regression
ridge=Ridge()
ridge.fit(X_train,y_train)
predicted_ridge = ridge.predict(X_test)
print("Accuracy:",ridge.score(X_test, y_test))
#Plotting the prediction
figure, ax = plt.subplots()
ax.scatter(y_test, predicted_ridge)
ax.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red')
ax.set_xlabel('Actual')
ax.set_ylabel('Predicted')
ax.set_title("Actual Truth vs Predicted")
plt.show()
# Out:
# Accuracy: 0.8871211406486663

# %%
#Using Lasso Regression
lasso=Lasso()
lasso.fit(X_train,y_train)
predicted_lasso = lasso.predict(X_test)
print("Accuracy:",lasso.score(X_test, y_test))
#Plotting the prediction
figure, ax = plt.subplots()
ax.scatter(y_test, predicted_lasso)
ax.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red')
ax.set_xlabel('Actual')
ax.set_ylabel('Predicted')
ax.set_title("Actual Truth vs Predicted")
plt.show()
# Out:
# Accuracy: 0.8874486042049451

# %%
#Using Random Forest Regression
forest=RandomForestRegressor()
forest.fit(X_train,y_train)
predicted_forest = forest.predict(X_test)
print("Accuracy:",forest.score(X_test, y_test))
#Plotting the prediction
figure, ax = plt.subplots()
ax.scatter(y_test, predicted_forest)
ax.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red')
ax.set_xlabel('Actual')
ax.set_ylabel('Predicted')
ax.set_title("Actual Truth vs Predicted")
plt.show()
# Out:
# Accuracy: 0.987835411226674

# %%
#Using Decision Tree Regression
tree=DecisionTreeRegressor()
tree.fit(X_train,y_train)
predicted_tree = tree.predict(X_test)
print("Accuracy:",tree.score(X_test, y_test))
#Plotting the prediction
figure, ax = plt.subplots()
ax.scatter(y_test, predicted_tree)
ax.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red')
ax.set_xlabel('Actual')
ax.set_ylabel('Predicted')
ax.set_title("Actual Truth vs Predicted")
plt.show()
# Out:
# Accuracy: 0.9836757320232185

# %%
#Using Support Vector Regression
svr=SVR()
svr.fit(X_train,y_train)
predicted_svr = svr.predict(X_test)
print("Accuracy:",svr.score(X_test, y_test))
#Plotting the prediction
figure, ax = plt.subplots()
ax.scatter(y_test, predicted_svr)
ax.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red')
ax.set_xlabel('Actual')
ax.set_ylabel('Predicted')
ax.set_title("Actual Truth vs Predicted")
plt.show()
# Out:
# Accuracy: 0.6449574999207335

# %%
results = {'Regression_Model': ["Linear Regression","Elastic Net","Ridge Regression","Lasso Regression","Random Forest","Decision Tree","Support Vector"],
        'Accuracy': [0.886,0.887,0.887,0.887,0.987, 0.983,0.644]
          }
df = pd.DataFrame(results, columns = ['Regression_Model', 'Accuracy'])
print(df)
# Out:
#     Regression_Model  Accuracy
# 0  Linear Regression     0.886
# 1        Elastic Net     0.887
# 2   Ridge Regression     0.887
# 3   Lasso Regression     0.887
# 4      Random Forest     0.987
# 5      Decision Tree     0.983
# 6     Support Vector     0.644

# %%
#Performing the same steps for NOX which is strongly correlated with AGE,TAX,INDUS
X2=Housing_data[['AGE','TAX','INDUS']]
y2=Housing_data['NOX']

# %%
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, test_size = 0.20, random_state = 42)

# %%
#Using Linear Regression
linear2=LinearRegression()
linear2.fit(X2_train,y2_train)
predicted_linear2 = linear2.predict(X2_test) 
print("Accuracy:",linear2.score(X2_test, y2_test))
#Plotting the prediction
figure, ax = plt.subplots()
ax.scatter(y2_test, predicted_linear2)
ax.plot([min(y2_test), max(y2_test)], [min(y2_test), max(y2_test)], color='red')
ax.set_xlabel('Actual')
ax.set_ylabel('Predicted')
ax.set_title("Actual Truth vs Predicted")
plt.show()
# Out:
# Accuracy: 0.6890643380322135

# %%
#Using Elastic Net Regression
en2=ElasticNet()
en2.fit(X2_train,y2_train)
predicted_en2 = en2.predict(X2_test)
print("Accuracy:",en2.score(X2_test, y2_test))
#Plotting the prediction
figure, ax = plt.subplots()
ax.scatter(y2_test, predicted_en2)
ax.plot([min(y2_test), max(y2_test)], [min(y2_test), max(y2_test)], color='red')
ax.set_xlabel('Actual')
ax.set_ylabel('Predicted')
ax.set_title("Actual Truth vs Predicted")
plt.show()
# Out:
# Accuracy: 0.6993439686367089

# %%
#Using Ridge Regression
ridge2=Ridge()
ridge2.fit(X2_train,y2_train)
predicted_ridge2 = ridge2.predict(X2_test)
print("Accuracy:",ridge2.score(X2_test, y2_test))
#Plotting the prediction
figure, ax = plt.subplots()
ax.scatter(y2_test, predicted_ridge2)
ax.plot([min(y2_test), max(y2_test)], [min(y2_test), max(y2_test)], color='red')
ax.set_xlabel('Actual')
ax.set_ylabel('Predicted')
ax.set_title("Actual Truth vs Predicted")
plt.show()
# Out:
# Accuracy: 0.6890731434645614

# %%
#Using Lasso Regression
lasso2=Lasso()
lasso2.fit(X2_train,y2_train)
predicted_lasso2 = lasso2.predict(X2_test)
print("Accuracy:",lasso2.score(X2_test, y2_test))
#Plotting the prediction
figure, ax = plt.subplots()
ax.scatter(y2_test, predicted_lasso2)
ax.plot([min(y2_test), max(y2_test)], [min(y2_test), max(y2_test)], color='red')
ax.set_xlabel('Actual')
ax.set_ylabel('Predicted')
ax.set_title("Actual Truth vs Predicted")
plt.show()
# Out:
# Accuracy: 0.6452630895629433

# %%
#Using Random Forest Regression
forest2=RandomForestRegressor()
forest2.fit(X2_train,y2_train)
predicted_forest2 = forest2.predict(X2_test)
print("Accuracy:",forest2.score(X2_test, y2_test))
#Plotting the prediction
figure, ax = plt.subplots()
ax.scatter(y2_test, predicted_forest2)
ax.plot([min(y2_test), max(y2_test)], [min(y2_test), max(y2_test)], color='red')
ax.set_xlabel('Actual')
ax.set_ylabel('Predicted')
ax.set_title("Actual Truth vs Predicted")
plt.show()
# Out:
# Accuracy: 0.8080160127005768

# %%
#Using Decision Tree Regression
tree2=DecisionTreeRegressor()
tree2.fit(X2_train,y2_train)
predicted_tree2 = tree2.predict(X2_test)
print("Accuracy:",tree2.score(X2_test, y2_test))
#Plotting the prediction
figure, ax = plt.subplots()
ax.scatter(y2_test, predicted_tree2)
ax.plot([min(y2_test), max(y2_test)], [min(y2_test), max(y2_test)], color='red')
ax.set_xlabel('Actual')
ax.set_ylabel('Predicted')
ax.set_title("Actual Truth vs Predicted")
plt.show()
# Out:
# Accuracy: 0.7368565475392921

# %%
#Using Support Vector Regression
svr2=SVR()
svr2.fit(X2_train,y2_train)
predicted_svr2 = svr2.predict(X2_test)
print("Accuracy:",svr2.score(X2_test, y2_test))
#Plotting the prediction
figure, ax = plt.subplots()
ax.scatter(y2_test, predicted_svr2)
ax.plot([min(y2_test), max(y2_test)], [min(y2_test), max(y2_test)], color='red')
ax.set_xlabel('Actual')
ax.set_ylabel('Predicted')
ax.set_title("Actual Truth vs Predicted")
plt.show()
# Out:
# Accuracy: 0.6476205459258046

# %%
results = {'Regression_Model': ["Linear Regression","Elastic Net","Ridge Regression","Lasso Regression","Random Forest","Decision Tree","Support Vector"],
        'Accuracy': [0.689,0.699,0.689,0.645,0.808, 0.736,0.647]
          }
df = pd.DataFrame(results, columns = ['Regression_Model', 'Accuracy'])
print(df)
# Out:
#     Regression_Model  Accuracy
# 0  Linear Regression     0.689
# 1        Elastic Net     0.699
# 2   Ridge Regression     0.689
# 3   Lasso Regression     0.645
# 4      Random Forest     0.808
# 5      Decision Tree     0.736
# 6     Support Vector     0.647

# %%
print("Observations and Understanding")
print("1. Random Forest has the maximum accuracy.")
print("2. Support Vector has the worst accuracy")
print("3. The values that do not lie on the prediction line have more deviations and therfore we can say they have less accuracy")
print("4. With stronger correlation amongst the features TAX has higher accuracy whereas NoX have less accuracy as it less correlated")
print("Understanding on the models")
print("1. When there is a linear relationship between the variables then we use Linear Regression. To minimize the residual sum of squares between the observed targets, it fits a linear model with weight coefficient. Linear Approximation is used to predict the targets.")
print("2. L2 regularization is used in ridge Regression.To minimize a penalized residual sum of squares the ridge coefficients are used. The coeffients are more robust to collinearity.")
print("3. Coefficients are minimized to zero in Lasso Regression. It used L1 regularization. If there are more than one predictors it chooses one and reduces other to zero giving less number of features.")
print("4. It uses both L1 and L2 regularization.Elastic Net is used when variables are highly correlated and prone to double shrinkage.")
print("5. Decision Tree Algorithm is used for solving regression and classification problems. It is supervised learning algorithm.")
print("6. Random Forest Regression is a combination of decision trees. It reduces variance giving the best accuracy.")
print("7. Support vector regression is dependant on weight instances and therefore it is very noisy which reduces the accuracy. Changing the number of features can help to improve the accuracy.")
# Out:
# Observations and Understanding
# 1. Random Forest has the maximum accuracy.
# 2. Support Vector has the worst accuracy
# 3. The values that do not lie on the prediction line have more deviations and therfore we can say they have less accuracy
# 4. With stronger correlation amongst the features TAX has higher accuracy whereas NoX have less accuracy as it less correlated
# Understanding on the models
# 1. When there is a linear relationship between the variables then we use Linear Regression. To minimize the residual sum of squares between the observed targets, it fits a linear model with weight coefficient. Linear Approximation is used to predict the targets.
# 2. L2 regularization is used in ridge Regression.To minimize a penalized residual sum of squares the ridge coefficients are used. The coeffients are more robust to collinearity.
# 3. Coefficients are minimized to zero in Lasso Regression. It used L1 regularization. If there are more than one predictors it chooses one and reduces other to zero giving less number of features.
# 4. It uses both L1 and L2 regularization.Elastic Net is used when variables are highly correlated and prone to double shrinkage.
# 5. Decision Tree Algorithm is used for solving regression and classification problems. It is supervised learning algorithm.
# 6. Random Forest Regression is a combination of decision trees. It reduces variance giving the best accuracy.
# 7. Support vector regression is dependant on weight instances and therefore it is very noisy which reduces the accuracy. Changing the number of features can help to improve the accuracy.
