# %% [markdown]
# <h1>AdaBoost Classifier using Decision Tree model as base on PhishingVsBenignURL data set</h1>

# %%
#Importing Libraries
from sklearn import metrics
from sklearn.model_selection import train_test_split 
from sklearn.tree import DecisionTreeClassifier
import pandas as pd 
import numpy as np 
from sklearn import tree
from sklearn.ensemble import AdaBoostClassifier

# %%
#Loading the csv to the dataframe
data = pd.read_csv(r"C:\Users\palak\Downloads\DataSetForPhishingVSBenignUrl.csv")
# Out:
# C:\Users\palak\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (31) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#Displaying the dataframe
data.head()
# Out:
#    Querylength  domain_token_count  path_token_count  avgdomaintokenlen  \
# 0            0                   4                 5                5.5
# 1            0                   4                 5                5.5
# 2            0                   4                 5                5.5
# 3            0                   4                12                5.5
# 4            0                   4                 6                5.5
#
#    longdomaintokenlen  avgpathtokenlen  tld  charcompvowels  charcompace  \
# 0                  14         4.400000    4               8            3
# 1                  14         6.000000    4              12            4
# 2                  14         5.800000    4              12            5
# 3                  14         5.500000    4              32           16
# 4                  14         7.333334    4              18           11
#
#    ldl_url  ...  SymbolCount_FileName  SymbolCount_Extension  \
# ...

# %%
#Encoding the values to use as target variables
#Target Variables Phising vs Non Phising for encoding the values
encoding_conditions = [(data['URL_Type_obf_Type'] == 'phishing'), (data['URL_Type_obf_Type'] != 'phishing')]
# Assigning the conditions with the encoding values.
encoding_values = [0,1]
#encoding_conditions and encoding_values as parameters to np.select and creating new column.
data['obf_Type'] = np.select(encoding_conditions, encoding_values)
#displaying
data.head()
# Out:
#    Querylength  domain_token_count  path_token_count  avgdomaintokenlen  \
# 0            0                   4                 5                5.5
# 1            0                   4                 5                5.5
# 2            0                   4                 5                5.5
# 3            0                   4                12                5.5
# 4            0                   4                 6                5.5
#
#    longdomaintokenlen  avgpathtokenlen  tld  charcompvowels  charcompace  \
# 0                  14         4.400000    4               8            3
# 1                  14         6.000000    4              12            4
# 2                  14         5.800000    4              12            5
# 3                  14         5.500000    4              32           16
# 4                  14         7.333334    4              18           11
#
#    ldl_url  ...  SymbolCount_Extension  SymbolCount_Afterpath  Entropy_URL  \
# ...

# %%
data=data.drop(columns='URL_Type_obf_Type')

# %%
#Dropping the rows that has infinity and nan as their values so that we can get more accurate analysis
data.replace([np.inf, -np.inf], np.nan)
data.dropna(inplace=True)
data
# Out:
#        Querylength  domain_token_count  path_token_count  avgdomaintokenlen  \
# 35               0                   4                 4           6.250000
# 37              22                   4                10           6.250000
# 38              23                   4                10           6.250000
# 39              22                   4                10           6.250000
# 40              23                   4                10           6.250000
# ...            ...                 ...               ...                ...
# 36702           29                   4                14           5.750000
# 36703            0                   4                13           3.750000
# 36704           58                   3                27           6.666666
# 36705           35                   3                13           4.333334
# 36706           40                   3                25           6.666666
#
# ...

# %%
#X has all the features and y has target variables
y = data[['obf_Type']] 
X = data.drop(['obf_Type', ], axis = 1)
print(y.shape, X.shape)
# Out:
# (18982, 1) (18982, 79)

# %%
X
# Out:
#        Querylength  domain_token_count  path_token_count  avgdomaintokenlen  \
# 35               0                   4                 4           6.250000
# 37              22                   4                10           6.250000
# 38              23                   4                10           6.250000
# 39              22                   4                10           6.250000
# 40              23                   4                10           6.250000
# ...            ...                 ...               ...                ...
# 36702           29                   4                14           5.750000
# 36703            0                   4                13           3.750000
# 36704           58                   3                27           6.666666
# 36705           35                   3                13           4.333334
# 36706           40                   3                25           6.666666
#
# ...

# %%
#Splitting the data into testing and training
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = np.random)
y_test=y_test.astype('int')
y_train=y_train.astype('int')
print(X_train.shape, y_train.shape) 
print(X_test.shape, y_test.shape)
# Out:
# (15185, 79) (15185, 1)
# (3797, 79) (3797, 1)

# %% [markdown]
# <h1>Gini Impurity</h1>

# %%
#Decision Tree Classifier with max_depth = 1 
gi1 = DecisionTreeClassifier(criterion = "gini",random_state = 50, max_depth=1, min_samples_leaf=5)
adaboost1=AdaBoostClassifier(gi1)
adaboost1.fit(X_train, y_train)
print("Accuracy:", metrics.accuracy_score(adaboost1.predict(X_test), y_test))
# Out:
# C:\Users\palak\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# Accuracy: 0.9228338161706611

# %%
#Decision Tree Classifier with max_depth = 3
gi3 = DecisionTreeClassifier(criterion = "gini",random_state = 50, max_depth=3, min_samples_leaf=5)
adaboost3=AdaBoostClassifier(gi3)
adaboost3.fit(X_train, y_train)
print("Accuracy:", metrics.accuracy_score(adaboost3.predict(X_test), y_test))
# Out:
# C:\Users\palak\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# Accuracy: 0.9654990782196471

# %%
#Decision Tree Classifier with max_depth = 6
gi6 = DecisionTreeClassifier(criterion = "gini",random_state = 50, max_depth=6, min_samples_leaf=5)
adaboost6=AdaBoostClassifier(gi6)
adaboost6.fit(X_train, y_train)
print("Accuracy:", metrics.accuracy_score(adaboost6.predict(X_test), y_test))
# Out:
# C:\Users\palak\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# Accuracy: 0.9636555175138267

# %%
#Decision Tree Classifier with max_depth = 9
gi9 = DecisionTreeClassifier(criterion = "gini",random_state = 50, max_depth=9, min_samples_leaf=5)
adaboost9=AdaBoostClassifier(gi9)
adaboost9.fit(X_train, y_train)
print("Accuracy:", metrics.accuracy_score(adaboost9.predict(X_test), y_test))
# Out:
# C:\Users\palak\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# Accuracy: 0.9749802475638663

# %%
#Decision Tree Classifier with max_depth = 12
gi12 = DecisionTreeClassifier(criterion = "gini",random_state = 50, max_depth=12, min_samples_leaf=5)
adaboost12=AdaBoostClassifier(gi12)
adaboost12.fit(X_train, y_train)
print("Accuracy:", metrics.accuracy_score(adaboost12.predict(X_test), y_test))
# Out:
# C:\Users\palak\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# Accuracy: 0.9757703450092178

# %%
#Decision Tree Classifier with max_depth = 15
gi15 = DecisionTreeClassifier(criterion = "gini",random_state = 50, max_depth=15, min_samples_leaf=5)
adaboost15=AdaBoostClassifier(gi15)
adaboost15.fit(X_train, y_train)
print("Accuracy:", metrics.accuracy_score(adaboost15.predict(X_test), y_test))
# Out:
# C:\Users\palak\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# Accuracy: 0.9762970766394522

# %%
#Decision Tree Classifier with max_depth = 18
gi18 = DecisionTreeClassifier(criterion = "gini",random_state = 50, max_depth=18, min_samples_leaf=5)
adaboost18=AdaBoostClassifier(gi18)
adaboost18.fit(X_train, y_train)
print("Accuracy:", metrics.accuracy_score(adaboost18.predict(X_test), y_test))
# Out:
# C:\Users\palak\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# Accuracy: 0.9741901501185146

# %% [markdown]
# <h1> Entropy Impurity</h1>

# %%
#Decision Tree Classifier with max_depth = 1
ei1 = DecisionTreeClassifier(criterion = "entropy",random_state = 50, max_depth=1, min_samples_leaf=5)
adaboostei1=AdaBoostClassifier(ei1)
adaboostei1.fit(X_train, y_train)
print("Accuracy:", metrics.accuracy_score(adaboostei1.predict(X_test), y_test))
# Out:
# C:\Users\palak\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# Accuracy: 0.9207268896497235

# %%
#Decision Tree Classifier with max_depth = 3
ei3 = DecisionTreeClassifier(criterion = "entropy",random_state = 50, max_depth=3, min_samples_leaf=5)
adaboostei3=AdaBoostClassifier(ei3)
adaboostei3.fit(X_train, y_train)
print("Accuracy:", metrics.accuracy_score(adaboostei3.predict(X_test), y_test))
# Out:
# C:\Users\palak\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# Accuracy: 0.9615485909928891

# %%
#Decision Tree Classifier with max_depth = 6
ei6 = DecisionTreeClassifier(criterion = "entropy",random_state = 50, max_depth=6, min_samples_leaf=5)
adaboostei6=AdaBoostClassifier(ei6)
adaboostei6.fit(X_train, y_train)
print("Accuracy:", metrics.accuracy_score(adaboostei6.predict(X_test), y_test))
# Out:
# C:\Users\palak\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# Accuracy: 0.9662891756649987

# %%
#Decision Tree Classifier with max_depth = 9
ei9 = DecisionTreeClassifier(criterion = "entropy",random_state = 50, max_depth=9, min_samples_leaf=5)
adaboostei9=AdaBoostClassifier(ei9)
adaboostei9.fit(X_train, y_train)
print("Accuracy:", metrics.accuracy_score(adaboostei9.predict(X_test), y_test))
# Out:
# C:\Users\palak\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# Accuracy: 0.9755069791941006

# %%
#Decision Tree Classifier with max_depth = 12
ei12 = DecisionTreeClassifier(criterion = "entropy",random_state = 50, max_depth=12, min_samples_leaf=5)
adaboostei12=AdaBoostClassifier(ei12)
adaboostei12.fit(X_train, y_train)
print("Accuracy:", metrics.accuracy_score(adaboostei12.predict(X_test), y_test))
# Out:
# C:\Users\palak\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# Accuracy: 0.9765604424545694

# %%
#Decision Tree Classifier with max_depth = 15
ei15 = DecisionTreeClassifier(criterion = "entropy",random_state = 50, max_depth=15, min_samples_leaf=5)
adaboostei15=AdaBoostClassifier(ei15)
adaboostei15.fit(X_train, y_train)
print("Accuracy:", metrics.accuracy_score(adaboostei15.predict(X_test), y_test))
# Out:
# C:\Users\palak\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# Accuracy: 0.9744535159336318

# %%
#Decision Tree Classifier with max_depth = 18
ei18 = DecisionTreeClassifier(criterion = "entropy",random_state = 50, max_depth=18, min_samples_leaf=5)
adaboostei18=AdaBoostClassifier(ei18)
adaboostei18.fit(X_train, y_train)
print("Accuracy:", metrics.accuracy_score(adaboostei18.predict(X_test), y_test))
# Out:
# C:\Users\palak\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# Accuracy: 0.9781406373452726

# %%
results = {'Depth': [1,2,3,4,5,6],
        'Accuracy_Gini': [0.785,0.843,0.874,0.891, 0.897,0.912],
        'Accuracy_Entropy': [0.785,0.843,0.874,0.874,0.895,0.906]
          }
df = pd.DataFrame(results, columns = ['Depth', 'Accuracy_Gini', 'Accuracy_Entropy'])
print(df)
# Out:
#    Depth  Accuracy_Gini  Accuracy_Entropy
# 0      1          0.785             0.785
# 1      2          0.843             0.843
# 2      3          0.874             0.874
# 3      4          0.891             0.874
# 4      5          0.897             0.895
# 5      6          0.912             0.906

# %%
results = {'Depth': [1,3,6,9,12,15,18],
        'Accuracy_Gini': [0.9228,0.9654,0.9636,0.9749,0.9757,0.9762,0.9741],
        'Accuracy_Entropy': [0.9207,0.9615,0.9662,0.9755,0.9765,0.9744,0.9781]
          }
df = pd.DataFrame(results, columns = ['Depth', 'Accuracy_Gini', 'Accuracy_Entropy'])
df
# Out:
#    Depth  Accuracy_Gini  Accuracy_Entropy
# 0      1         0.9228            0.9207
# 1      3         0.9654            0.9615
# 2      6         0.9636            0.9662
# 3      9         0.9749            0.9755
# 4     12         0.9757            0.9765
# 5     15         0.9762            0.9744
# 6     18         0.9741            0.9781

# %%
print("Understanding and Discussions:")
print("Accuracy of AdaBoost on Decision Tree is highter than Decision Tree Model.")
print("until depth 9, Accuracy of Gini is more than entropy.After which accuracy of entropy is more than gini.")
print("We can say that adaboost does not change the behaviour instead just improves the accuracy as we have seen the similar behaviour in accuracies before.")
print("From depth 18, both tree overfit which leads to decrease in the accuracy.")
# Out:
# Understanding and Discussions:
# Accuracy of AdaBoost on Decision Tree is highter than Decision Tree Model.
# until depth 9, Accuracy of Gini is more than entropy.After which accuracy of entropy is more than gini.
# We can say that adaboost does not change the behaviour instead just improves the accuracy as we have seen the similar behaviour in accuracies before.
# From depth 18, both tree overfit which leads to decrease in the accuracy.
